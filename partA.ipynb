# %% [markdown]
# ## Importing Dependencies

# %%
import pandas as pd
import numpy as np
from classes.preprocessing import Preprocessing
from classes.perceptron import Perceptron

# %% [markdown]
# ## PM1

# %%
df = pd.read_csv('data/cancer.csv')
y = df["diagnosis"]
y.replace('M',1,inplace=True)
y.replace('B',-1,inplace=True) 
X = df.drop(df.columns[[0,1]],axis=1)

# %%
X
# Out:
#      radius_mean  texture_mean  ...  symmetry_worst  fractal_dimension_worst
# 0          17.99         10.38  ...          0.4601                  0.11890
# 1          20.57         17.77  ...          0.2750                  0.08902
# 2          19.69         21.25  ...          0.3613                  0.08758
# 3          11.42         20.38  ...          0.6638                  0.17300
# 4          20.29         14.34  ...          0.2364                  0.07678
# ..           ...           ...  ...             ...                      ...
# 564        21.56         22.39  ...          0.2060                  0.07115
# 565        20.13         28.25  ...          0.2572                  0.06637
# 566        16.60         28.08  ...          0.2218                  0.07820
# 567        20.60         29.33  ...          0.4087                  0.12400
# 568         7.76         24.54  ...          0.2871                  0.07039
#
# [569 rows x 30 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 564    1
# 565    1
# 566    1
# 567    1
# 568   -1
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# ## Train Test Split

# %%
preprocessor = Preprocessing()
X_train, X_test = preprocessor.train_test_split(X)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 2
#       1 preprocessor = Preprocessing()
# ----> 2 X_train, X_test = preprocessor.train_test_split(X)
#
# File ~/Desktop/Acads/ML/ML_assignment_1/classes/preprocessing.py:18, in Preprocessing.train_test_split(df, train_size, test_size, random_state)
#      17 def train_test_split(self,df,train_size=0.67,test_size = 0.33,random_state=0):
# ---> 18     train = df.sample(frac= train_size,random_state = random_state)
#      19     test = df.drop(train.index)
#      20     return train, test
#
# AttributeError: 'Preprocessing' object has no attribute 'sample'

# %% [markdown]
# ## PM1

# %%
PM1 = Perceptron()
PM1.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 PM1 = Perceptron()
# ----> 2 PM1.fit(X_train,y_train)
#
# NameError: name 'X_train' is not defined
